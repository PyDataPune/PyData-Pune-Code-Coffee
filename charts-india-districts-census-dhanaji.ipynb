# %%
import pandas as pd
import matplotlib.pyplot as plt
from pandas_highcharts.display import display_charts

# Get needed data file
input_file = '..\data\india-districts-census-2011.csv'
df = pd.read_csv(input_file)
# Out:
# <script src="//code.highcharts.com/stock/highstock.js"></script>
# <script src="//code.highcharts.com/highcharts-more.js"></script>
# <script src="//code.highcharts.com/modules/exporting.js"></script>

# %%
df.describe()
# Out:
#        District code    Population          Male        Female      Literate  \
# count     640.000000  6.400000e+02  6.400000e+02  6.400000e+02  6.400000e+02
# mean      320.500000  1.891961e+06  9.738598e+05  9.181011e+05  1.193186e+06
# std       184.896367  1.544380e+06  8.007785e+05  7.449864e+05  1.068583e+06
# min         1.000000  8.004000e+03  4.414000e+03  3.590000e+03  4.436000e+03
# 25%       160.750000  8.178610e+05  4.171682e+05  4.017458e+05  4.825982e+05
# 50%       320.500000  1.557367e+06  7.986815e+05  7.589200e+05  9.573465e+05
# 75%       480.250000  2.583551e+06  1.338604e+06  1.264277e+06  1.602260e+06
# max       640.000000  1.106015e+07  5.865078e+06  5.195070e+06  8.227161e+06
#
#        Male_Literate  Female_Literate            SC       Male_SC  \
# count   6.400000e+02     6.400000e+02  6.400000e+02  6.400000e+02
# mean    6.793182e+05     5.138675e+05  3.146537e+05  1.617739e+05
# std     5.924144e+05     4.801816e+05  3.129818e+05  1.611216e+05
# ...

# %%
# Task 05 - State wise male and female population in India
df_population = df[['State Name', 'Male','Female', 'Population']]
mf_population =  df_population.groupby(['State Name'])[['Male','Female','Population']].sum().rename(columns={'Population':'TOTAL'})
display_charts(mf_population, title="India's population - Male and Females", kind="bar", figsize = (1000, 700))
# Out:
# <div id="chart_idfuzQlJfN"</div>
# ...

# %%
# 07 - Population of different types of age groups in India

df_age_group = df.groupby(['State Name'])[['Age_Group_0_29','Age_Group_30_49','Age_Group_50']].sum().rename(columns={'Age_Group_0_29':'0-29 YEARS','Age_Group_30_49':'30-49 YEARS','Age_Group_50':'50 YEARS & ABOVE'})
display_charts(df_age_group, title="State wise different age groups in India", kind="barh",figsize = (1000, 700))
# Out:
# <div id="chart_idbfvTRsdT"</div>
# ...

# %%
# Task 09 - Religion's distribution in India

df_reg = df[['Hindus', 'Muslims', 'Christians', 'Sikhs', 'Buddhists','Jains','Others_Religions','Religion_Not_Stated']].sum()
df_religion = pd.DataFrame(df_reg)

df_religion.rename(columns={0:'RELIGIONS'})

display_charts(df_religion, kind='pie', title="Religions in India")
# Out:
# <div id="chart_idsbNSIzTJ"</div>
#     <script type="text/javascript">new Highcharts.Chart({"legend":{"enabled":true},"series":[{"yAxis":0,"name":0,"data":[["Hindus",966257353],["Muslims",172245158],["Christians",27819588],["Sikhs",20833116],["Buddhists",8442972],["Jains",4451753],["Others_Religions",7937734],["Religion_Not_Stated",2867303]]}],"chart":{"renderTo":"chart_idsbNSIzTJ","type":"pie"},"yAxis":[{}],"title":{"text":"Religions in India"},"xAxis":{"categories":["Hindus","Muslims","Christians","Sikhs","Buddhists","Jains","Others_Religions","Religion_Not_Stated"]}});</script>
