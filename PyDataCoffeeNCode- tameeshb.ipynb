# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas_highcharts.core import serialize
from pandas_highcharts.display import display_charts
from IPython.display import display
# Out:
# <script src="//code.highcharts.com/stock/highstock.js"></script>
# <script src="//code.highcharts.com/highcharts-more.js"></script>
# <script src="//code.highcharts.com/modules/exporting.js"></script>

# %%
dataCen = pd.read_csv('csvs/india-districts-census-2011.csv', encoding='utf-8')

# %%
dataD = dataCen[['State Name','Literate']]

# %%
dataD2 = dataD.groupby(['State Name'])[['Literate']].sum()

# %%
dataD2
# Out:
#                               Literate
# State Name
# ANDAMAN AND NICOBAR ISLANDS     294281
# ANDHRA PRADESH                50556760
# ARUNACHAL PRADESH               766005
# ASSAM                         19177977
# BIHAR                         52504553
# CHANDIGARH                      805438
# CHHATTISGARH                  15379922
# DADRA AND NAGAR HAVELI          223230
# DAMAN AND DIU                   188406
# GOA                            1165487
# GUJARAT                       41093358
# HARYANA                       16598988
# HIMACHAL PRADESH               5039736
# JAMMU AND KASHMIR              7067233
# JHARKHAND                     18328069
# KARNATAKA                     40647322
# KERALA                        28135824
# LAKSHADWEEP                      52553
# MADHYA PRADESH                42851169
# MAHARASHTRA                   81554290
# MANIPUR                        1908476
# MEGHALAYA                      1785005
# MIZORAM                         848175
# ...

# %%
display_charts(dataD2, title="Literacy in different states of India",kind="bar",figsize = (1000, 700))
# Out:
# <div id="chart_idXxnRseEM"</div>
# ...

# %%
dataR = dataCen[['State Name','Hindus','Muslims','Christians','Sikhs','Buddhists','Jains','Others_Religions']]

# %%
dataR = dataR.groupby(['State Name'])[['Hindus','Muslims','Christians','Sikhs','Buddhists','Jains','Others_Religions']].sum()

# %%
dataR
# Out:
#                                 Hindus   Muslims  Christians     Sikhs  \
# State Name
# ANDAMAN AND NICOBAR ISLANDS     264296     32413       80984      1286
# ANDHRA PRADESH                74824149   8082412     1129784     40244
# ARUNACHAL PRADESH               401876     27045      418732      3287
# ASSAM                         19180759  10679345     1165867     20672
# BIHAR                         86078686  17557809      129247     23779
# CHANDIGARH                      852574     51447        8720    138329
# CHHATTISGARH                  23819789    514998      490542     70036
# DADRA AND NAGAR HAVELI          322857     12922        5113       217
# DAMAN AND DIU                   220150     19277        2820       172
# GOA                             963877    121564      366130      1473
# GUJARAT                       53533988   5846761      316178     58246
# HARYANA                       22171128   1781342       50353   1243752
# ...

# %%
display_charts(dataR, title="Religion dist of India",kind="bar",figsize = (1000, 900))
# Out:
# <div id="chart_idKZhfPvDF"</div>
# ...

# %%
dataP = dataCen[['State Name','SC','Population']]
dataP = dataP.groupby(['State Name'])[['SC','Population']].sum()

# %%
dataP
# Out:
#                                    SC  Population
# State Name
# ANDAMAN AND NICOBAR ISLANDS         0      380581
# ANDHRA PRADESH               13878078    84580777
# ARUNACHAL PRADESH                   0     1383727
# ASSAM                         2231321    31205576
# BIHAR                        16567325   104099452
# CHANDIGARH                     199086     1055450
# CHHATTISGARH                  3274269    25545198
# DADRA AND NAGAR HAVELI           6186      343709
# DAMAN AND DIU                    6124      243247
# GOA                             25449     1458545
# GUJARAT                       4074447    60439692
# HARYANA                       5113615    25351462
# HIMACHAL PRADESH              1729252     6864602
# JAMMU AND KASHMIR              924991    12541302
# JHARKHAND                     3985644    32988134
# KARNATAKA                    10474992    61095297
# KERALA                        3039573    33406061
# ...

# %%
perc = (dataP.SC*100/dataP.Population)
dataP['perc'] = perc

# %%
dataP
# Out:
#                                    SC  Population       perc
# State Name
# ANDAMAN AND NICOBAR ISLANDS         0      380581   0.000000
# ANDHRA PRADESH               13878078    84580777  16.408076
# ARUNACHAL PRADESH                   0     1383727   0.000000
# ASSAM                         2231321    31205576   7.150392
# BIHAR                        16567325   104099452  15.914901
# CHANDIGARH                     199086     1055450  18.862665
# CHHATTISGARH                  3274269    25545198  12.817552
# DADRA AND NAGAR HAVELI           6186      343709   1.799778
# DAMAN AND DIU                    6124      243247   2.517606
# GOA                             25449     1458545   1.744821
# GUJARAT                       4074447    60439692   6.741343
# HARYANA                       5113615    25351462  20.170888
# HIMACHAL PRADESH              1729252     6864602  25.190856
# JAMMU AND KASHMIR              924991    12541302   7.375558
# ...

# %%
dataP = dataP.groupby(['State Name'])[['perc']].sum()
display_charts(dataP, title="SC % Statewise",kind="bar",figsize = (1000, 900))
# Out:
# <div id="chart_idCvNIjHpq"</div>
# ...

# %%
dataP = dataCen[['State Name','ST','Population']]
dataP = dataP.groupby(['State Name'])[['ST','Population']].sum()
perc = (dataP.ST*100/dataP.Population)
dataP['perc'] = perc
dataP = dataP.groupby(['State Name'])[['perc']].sum()
display_charts(dataP, title="ST % Statewise",kind="bar",figsize = (1000, 900))
# Out:
# <div id="chart_idpbRWsvlf"</div>
# ...
